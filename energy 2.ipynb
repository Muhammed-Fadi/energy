# %%
#importing numpy,pandas,matplotlib and seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('energy.csv') #reading the csv file

# %%
data
# Out:
#         X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0     0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1     0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2     0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3     0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4     0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28
# ...    ...    ...    ...     ...  ...  ...  ...  ...    ...    ...
# 1291   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1292   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1293   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1294   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1295   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
#
# [1296 rows x 10 columns]

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#         X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0     0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1     0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2     0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3     0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4     0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28
# ...    ...    ...    ...     ...  ...  ...  ...  ...    ...    ...
# 1291   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1292   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1293   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1294   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1295   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
#
# [1296 rows x 10 columns]

# %%
df.head(10)                                  #taking fisrt five
# Out:
#      X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28
# 5  0.90  563.5  318.5  122.50  7.0  3.0  0.0  0.0  21.46  25.38
# 6  0.90  563.5  318.5  122.50  7.0  4.0  0.0  0.0  20.71  25.16
# 7  0.90  563.5  318.5  122.50  7.0  5.0  0.0  0.0  19.68  29.60
# 8  0.86  588.0  294.0  147.00  7.0  2.0  0.0  0.0  19.50  27.30
# 9  0.86  588.0  294.0  147.00  7.0  3.0  0.0  0.0  19.95  21.97

# %%
df.tail(5)              #taking last five
# Out:
#       X1  X2  X3  X4  X5  X6  X7  X8  Y1  Y2
# 1291 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1292 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1293 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1294 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1295 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    float64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    float64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(10)
# memory usage: 101.4 KB

# %% [markdown]
# handling missing values
# -----------------------

# %%
df.isnull()                       #checking for null values
# Out:
#          X1     X2     X3     X4     X5     X6     X7     X8     Y1     Y2
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1291   True   True   True   True   True   True   True   True   True   True
# 1292   True   True   True   True   True   True   True   True   True   True
# 1293   True   True   True   True   True   True   True   True   True   True
# 1294   True   True   True   True   True   True   True   True   True   True
# 1295   True   True   True   True   True   True   True   True   True   True
#
# [1296 rows x 10 columns]

# %%
df.isnull().sum()               #retriving the sum of the null value using sum()
# Out:
# X1    528
# X2    528
# X3    528
# X4    528
# X5    528
# X6    528
# X7    528
# X8    528
# Y1    528
# Y2    528
# dtype: int64

# %%
df1=df.dropna()                 #droping nan values

# %%
df1
# Out:
#        X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ...  ...  ...    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5  5.0  0.4  5.0  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5  2.0  0.4  5.0  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5  3.0  0.4  5.0  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5  4.0  0.4  5.0  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5  5.0  0.4  5.0  16.64  16.03
#
# [768 rows x 10 columns]

# %%
df1.info()            # checking the information df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    float64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    float64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(10)
# memory usage: 66.0 KB

# %%
df1.shape     #check the shape
# Out:
# (768, 10)

# %%
df1.columns          #retriving the columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2'], dtype='object')

# %%
df1.describe()             #description of df1
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# ...

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
df1.duplicated().sum()              #sum of duplicate value
# Out:
# np.int64(0)

# %%
df1=df1.rename(columns={'X1':'relative compactness','X2':'surface area','X3':'whole area','X4':'roof area','X5':'overall height','X6':'orientaion','X7':'glazing area','X8':'glazing area distubution','Y1':'heating load','Y2':'cooling load'})

# %%
df1
# Out:
#      relative compactness  surface area  whole area  roof area  \
# 0                    0.98         514.5       294.0     110.25
# 1                    0.98         514.5       294.0     110.25
# 2                    0.98         514.5       294.0     110.25
# 3                    0.98         514.5       294.0     110.25
# 4                    0.90         563.5       318.5     122.50
# ..                    ...           ...         ...        ...
# 763                  0.64         784.0       343.0     220.50
# 764                  0.62         808.5       367.5     220.50
# 765                  0.62         808.5       367.5     220.50
# 766                  0.62         808.5       367.5     220.50
# 767                  0.62         808.5       367.5     220.50
#
#      overall height  orientaion  glazing area  glazing area distubution  \
# 0               7.0         2.0           0.0                       0.0
# ...

# %%
sns.histplot(df1['heating load'],kde=True,color='blue')              #histplot for heatmap
# Out:
# <Axes: xlabel='heating load', ylabel='Count'>

# %%
sns.histplot(df1['cooling load'],kde=True,color='purple')        #histplot for cooling load
# Out:
# <Axes: xlabel='cooling load', ylabel='Count'>

# %%
sns.boxplot(data=df1)      #boxplot for sns
# Out:
# <Axes: >

# %%
c=df1.corr()           #creating corelation

# %%
c
# Out:
#                           relative compactness  surface area    whole area  \
# relative compactness              1.000000e+00 -9.919015e-01 -2.037817e-01
# surface area                     -9.919015e-01  1.000000e+00  1.955016e-01
# whole area                       -2.037817e-01  1.955016e-01  1.000000e+00
# roof area                        -8.688234e-01  8.807195e-01 -2.923165e-01
# overall height                    8.277473e-01 -8.581477e-01  2.809757e-01
# orientaion                        4.678592e-17 -3.459372e-17 -2.429499e-17
# glazing area                     -2.960552e-15  3.636925e-15 -8.567455e-17
# glazing area distubution         -7.107006e-16  2.438409e-15  2.067384e-16
# heating load                      6.222722e-01 -6.581202e-01  4.556712e-01
# cooling load                      6.343391e-01 -6.729989e-01  4.271170e-01
#
#                              roof area  overall height    orientaion  \
# relative compactness     -8.688234e-01    8.277473e-01  4.678592e-17
# ...

# %%
plt.figure(figsize=(10,8))                           #heatmap-visulizing co-realtion
sns.heatmap(c,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >

# %%
df1.skew() #skewness
# Out:
# relative compactness        0.495513
# surface area               -0.125131
# whole area                  0.533417
# roof area                  -0.162764
# overall height              0.000000
# orientaion                  0.000000
# glazing area               -0.060254
# glazing area distubution   -0.088689
# heating load                0.360449
# cooling load                0.395992
# dtype: float64

# %%
x=df1.drop(columns=['cooling load'])      #removing the cool load columns from df1 and store the rest in x

# %%
x.columns #view columns in x
# Out:
# Index(['relative compactness', 'surface area', 'whole area', 'roof area',
#        'overall height', 'orientaion', 'glazing area',
#        'glazing area distubution', 'heating load'],
#       dtype='object')

# %%
y=df1['cooling load']      #store the cooling load columns from df1 in y (target)

# %%
y    #calling y
# Out:
# 0      21.33
# 1      21.33
# 2      21.33
# 3      21.33
# 4      28.28
#        ...
# 763    21.40
# 764    16.88
# 765    17.11
# 766    16.61
# 767    16.03
# Name: cooling load, Length: 768, dtype: float64

# %%
from sklearn.feature_selection import SelectKBest,f_regression          #import sklearn

# %%
sk=SelectKBest(score_func=f_regression,k='all')        #select all features using the f_regrssion scoring function

# %%
x_new=sk.fit_transform(x,y)       #select the best features from x based on y

# %%
selected_columns=x.columns[sk.get_support()]      # get the name of the selected features

# %%
selected_columns
# Out:
# Index(['relative compactness', 'surface area', 'whole area', 'roof area',
#        'overall height', 'orientaion', 'glazing area',
#        'glazing area distubution', 'heating load'],
#       dtype='object')

# %%
xselected=x[selected_columns]

# %%
featurescore=pd.DataFrame({'features':x.columns,'score':sk.scores_}).sort_values(by='score',ascending=False)

# %%
featurescore
# Out:
#                    features         score
# 8              heating load  15294.814350
# 4            overall height   3111.127823
# 3                 roof area   2226.031391
# 1              surface area    634.180214
# 0      relative compactness    515.763924
# 2                whole area    170.921606
# 6              glazing area     34.466755
# 7  glazing area distubution      1.960440
# 5                orientaion      0.156443

# %% [markdown]
# scaling
# --------------------

# %%
from sklearn.preprocessing import StandardScaler      # importing the standardscaler

# %%
ss=StandardScaler()     # setting up the scaler

# %%
xscaled=ss.fit_transform(xselected)      #scaling the selection features

# %%
xscaled      #viewing the scaled ones
# Out:
# array([[ 2.04177671, -1.78587489, -0.56195149, ..., -1.76044698,
#         -1.81457514, -0.67011624],
#        [ 2.04177671, -1.78587489, -0.56195149, ..., -1.76044698,
#         -1.81457514, -0.67011624],
#        [ 2.04177671, -1.78587489, -0.56195149, ..., -1.76044698,
#         -1.81457514, -0.67011624],
#        ...,
#        [-1.36381225,  1.55394308,  1.12390297, ...,  1.2440492 ,
#          1.41133622, -0.58185433],
#        [-1.36381225,  1.55394308,  1.12390297, ...,  1.2440492 ,
#          1.41133622, -0.5778875 ],
#        [-1.36381225,  1.55394308,  1.12390297, ...,  1.2440492 ,
#          1.41133622, -0.56202019]])

# %%
from sklearn.model_selection import train_test_split     #importing train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(xscaled,y,test_size=0.2,random_state=42)         #split the data into training and testing sets

# %%
print('x_train shape:',x_train.shape)
print('x_test shape:',x_test.shape)
print('y_train shape:',y_train.shape)
print('y_test shape:',y_test.shape)
# Out:
# x_train shape: (614, 9)
# x_test shape: (154, 9)
# y_train shape: (614,)
# y_test shape: (154,)

# %%
from sklearn.linear_model import LinearRegression   #importing the alogritham---linear regression

# %%
LR=LinearRegression()    #create a linearregression object

# %%
LR.fit(x_train,y_train)      #training data
# Out:
# LinearRegression()

# %%
ypred_LR=LR.predict(x_test) # predicting

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score      #import mean_absolute_error,mean_squared_error,r2_error

# %%
mae=mean_absolute_error(y_test,ypred_LR)   #evaluvating predicted values ( mean_absolute_error,mean_squared_error,r2_score)

# %%
mae
# Out:
# 1.5055521585122214

# %%
mse=mean_squared_error(y_test,ypred_LR)

# %%
mse
# Out:
# 4.160178918056219

# %%
r2=r2_score(y_test,ypred_LR)

# %%
r2
# Out:
# 0.9551014139944851

# %%
from sklearn.svm import SVR

# %%
svr=SVR()

# %%
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
ypred_svr=svr.predict(x_test)     #predicting

# %%
mae=mean_absolute_error(y_test,ypred_svr)        #evaluvating predicted values ( mean_absolute_error,mean_squared_error,r2_score)
mse=mean_squared_error(y_test,ypred_svr)
r2=r2_score(y_test,ypred_svr)

# %%
print (mae)      #displaying the predicted value 
print (mse)
print (r2)
# Out:
# 1.6544206658105334
# 6.67628193423507
# 0.9279464598697176

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dr=DecisionTreeRegressor()    # create a decisiontree regression object

# %%
dr.fit(x_train,y_train)     # teaching
# Out:
# DecisionTreeRegressor()

# %%
ypred_dr=dr.predict(x_test)    #predicting

# %%
mae=mean_absolute_error(y_test,ypred_dr)    #evaluvating predicted values ( mean_absolute_error,mean_squared_error,r2_score)
mse=mean_squared_error(y_test,ypred_dr)
r2=r2_score(y_test,ypred_dr)

# %%
print (mae)  #displaying the predicted value
print (mse)
print (r2)
# Out:
# 0.945844155844156
# 3.648929870129871
# 0.9606190515289986
